# %%
import sys
import os

# %%
sys.path = ['/Users/nitta.yuya/study/deep-learning-from-scratch-2/.venv/lib/python3.13/site-packages']

# %%
parent = '..'
if parent not in sys.path:
    sys.path.append(parent)

# %%
sys.path
# Out:
# ['/Users/nitta.yuya/study/deep-learning-from-scratch-2/.venv/lib/python3.13/site-packages',
#  '..']

# %%
os.listdir()
# Out:
# ['ch07',
#  'LICENSE.md',
#  'ch08',
#  'ch06',
#  'ch01',
#  '.DS_Store',
#  'requirements.txt',
#  'dataset',
#  'path.ipynb',
#  'ch04',
#  'ch03',
#  'README.md',
#  'common',
#  'ch02',
#  'ch05',
#  '.venv',
#  '.github',
#  '.git']

# %%
import os, sys

for i in os.listdir():
    j = '../' + i
    if j not in sys.path:  # ← ここを not in にする
        sys.path.append(j)

# %%
sys.path
# Out:
# ['/Users/nitta.yuya/study/deep-learning-from-scratch-2/.venv/lib/python3.13/site-packages',
#  '..',
#  '../ch07',
#  '../LICENSE.md',
#  '../ch08',
#  '../ch06',
#  '../ch01',
#  '../.DS_Store',
#  '../requirements.txt',
#  '../dataset',
#  '../path.ipynb',
#  '../ch04',
#  '../ch03',
#  '../README.md',
#  '../common',
#  '../ch02',
#  '../ch05',
#  '../.venv',
#  '../.github',
#  '../.git']
